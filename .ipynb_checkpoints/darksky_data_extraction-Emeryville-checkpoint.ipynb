# %% [markdown]
# Dark Sky API: 4ff1d8e73db78778122dfacfabf261f2

# %%
from darksky import forecast
from datetime import datetime as dt
from datetime import date, timedelta
import pandas as pd

# %% [markdown]
# Using Time Machine Call, we can get the observed weather conditions for a date in the past or future.

# %%
longitudes = [-122.2970, -122.2961, -122.2985]
latitudes = [37.83967, 37.83657, 37.84656]
key = "4ff1d8e73db78778122dfacfabf261f2"

# %%
def get_forecast(lat, lon, day):
    # assumes month is April and year is 2018
    key = "4ff1d8e73db78778122dfacfabf261f2"
    t = dt(2018, 4, day, 12).isoformat()
    fcast = forecast(key, lat, lon, t, exclude=['currently','daily','flags'])
    return fcast['hourly']['data']

# %%
mydata = pd.DataFrame(get_forecast(latitudes[0], longitudes[0]), 4)
mydata['LAT'] = latitudes[0]
mydata['LON'] = longitudes[0]
mydata['YEAR'] = 2018
mydata['MONTH'] = 4
mydata['DAY'] = 4
mydata['HOUR'] = [i for i in range(24)]

# %%
for i in range(5, 8):
    for j in range(1, 3):
        tempdata = pd.DataFrame(get_forecast(latitudes[0], longitudes[0]), i)
        tempdata['LAT'] = latitudes[j]
        tempdata['LON'] = longitudes[j]
        tempdata['YEAR'] = 2018
        tempdata['MONTH'] = 4
        tempdata['DAY'] = i
        tempdata['HOUR'] = [i for i in range(24)]
        mydata = mydata.append(tempdata)

# %% [markdown]
# Save it as csv

# %%
mydata.to_csv("emeryville_4_4_to_4_7.csv")

# %% [markdown]
# ## mydata contains the hourly data from Apr 2 to Apr 27.
#
# one day has 24 hours record, so there are 26 days between Apr 2 to Apr 27. Therefore, we have 24*26 = 624 records.

# %%
mydata.shape
# Out:
# (624, 24)

# %% [markdown]
# The first 5 records in the data

# %%
mydata.head()
# Out:
#    DAY  HOUR      LAT       LON  MONTH  YEAR  apparentTemperature  cloudCover  \
# 0    2     0  38.5449 -121.7405      4  2018                57.36        0.00
# 1    2     1  38.5449 -121.7405      4  2018                56.39        0.00
# 2    2     2  38.5449 -121.7405      4  2018                55.80        0.08
# 3    2     3  38.5449 -121.7405      4  2018                54.51        0.08
# 4    2     4  38.5449 -121.7405      4  2018                52.95        0.08
#
#    dewPoint  humidity    ...     precipType  pressure  summary  temperature  \
# 0     48.96      0.74    ...            NaN   1010.51    Clear        57.36
# 1     48.27      0.74    ...            NaN   1010.65    Clear        56.39
# 2     47.70      0.74    ...            NaN   1010.53    Clear        55.80
# 3     47.69      0.78    ...            NaN   1010.45    Clear        54.51
# 4     46.80      0.80    ...            NaN   1010.09    Clear        52.95
#
#          time  uvIndex visibility  windBearing  windGust  windSpeed
# 0  1522652400      NaN       9.82          190       NaN       4.89
# 1  1522656000      NaN       9.82          197       NaN       5.16
# 2  1522659600      NaN       9.82          198       NaN       5.86
# 3  1522663200      NaN       9.82          206       NaN       5.02
# 4  1522666800      NaN       9.82          199       NaN       5.36
#
# [5 rows x 24 columns]

# %% [markdown]
# Returns a ForecastioDataPoint object

# %%
davis['currently']
# Out:
# {'apparentTemperature': 66.81,
#  'cloudCover': 0,
#  'dewPoint': 49.23,
#  'humidity': 0.53,
#  'icon': 'clear-day',
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'pressure': 1012.1,
#  'summary': 'Clear',
#  'temperature': 66.81,
#  'time': 1522695600,
#  'visibility': 9.64,
#  'windBearing': 302,
#  'windSpeed': 7.74}

# %%
davis['hourly']
# Out:
# {'data': [{'apparentTemperature': 51.86,
#    'cloudCover': 0.06,
#    'dewPoint': 45.2,
#    'humidity': 0.78,
#    'icon': 'clear-night',
#    'ozone': 343.2,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1013.81,
#    'summary': 'Clear',
#    'temperature': 51.86,
#    'time': 1524812400,
#    'uvIndex': 0,
#    'visibility': 9.49,
#    'windBearing': 204,
#    'windGust': 19.65,
#    'windSpeed': 11.75},
#   {'apparentTemperature': 51.36,
#    'cloudCover': 0.06,
#    'dewPoint': 45.26,
#    'humidity': 0.8,
#    'icon': 'clear-night',
#    'ozone': 344.79,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1014.08,
#    'summary': 'Clear',
#    'temperature': 51.36,
#    'time': 1524816000,
#    'uvIndex': 0,
#    'visibility': 9.45,
#    'windBearing': 206,
#    'windGust': 19.88,
#    'windSpeed': 10.6},
#   {'apparentTemperature': 51.16,
#    'cloudCover': 0.04,
#    'dewPoint': 45.19,
#    'humidity': 0.8,
#    'icon': 'clear-night',
#    'ozone': 347.18,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1014.57,
#    'summary': 'Clear',
#    'temperature': 51.16,
#    'time': 1524819600,
#    'uvIndex': 0,
#    'visibility': 9.45,
#    'windBearing': 203,
#    'windGust': 18.84,
#    'windSpeed': 9.48},
#   {'apparentTemperature': 50.19,
#    'cloudCover': 0.09,
#    'dewPoint': 45.17,
#    'humidity': 0.83,
#    'icon': 'clear-night',
#    'ozone': 350.93,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1014.88,
#    'summary': 'Clear',
#    'temperature': 50.19,
#    'time': 1524823200,
#    'uvIndex': 0,
#    'visibility': 9.71,
#    'windBearing': 200,
#    'windGust': 20.15,
#    'windSpeed': 7.91},
#   {'apparentTemperature': 50.44,
#    'cloudCover': 0.07,
#    'dewPoint': 45.35,
#    'humidity': 0.83,
#    'icon': 'clear-night',
#    'ozone': 355.47,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1015.45,
#    'summary': 'Clear',
#    'temperature': 50.44,
#    'time': 1524826800,
#    'uvIndex': 0,
#    'visibility': 9.49,
#    'windBearing': 196,
#    'windGust': 14.44,
#    'windSpeed': 7.81},
#   {'apparentTemperature': 50.59,
#    'cloudCover': 0.13,
#    'dewPoint': 45.09,
#    'humidity': 0.81,
#    'icon': 'clear-night',
#    'ozone': 359.68,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1016.13,
#    'summary': 'Clear',
#    'temperature': 50.59,
#    'time': 1524830400,
#    'uvIndex': 0,
#    'visibility': 9.49,
#    'windBearing': 198,
#    'windGust': 13.92,
#    'windSpeed': 6.89},
#   {'apparentTemperature': 50.17,
#    'cloudCover': 0.08,
#    'dewPoint': 44.95,
#    'humidity': 0.82,
#    'icon': 'clear-night',
#    'ozone': 363.97,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1016.82,
#    'summary': 'Clear',
#    'temperature': 50.17,
#    'time': 1524834000,
#    'uvIndex': 0,
#    'visibility': 9.44,
#    'windBearing': 199,
#    'windGust': 11.9,
#    'windSpeed': 5.27},
#   {'apparentTemperature': 50.84,
#    'cloudCover': 0.02,
#    'dewPoint': 45.71,
#    'humidity': 0.83,
#    'icon': 'clear-day',
#    'ozone': 367.76,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1017.86,
#    'summary': 'Clear',
#    'temperature': 50.84,
#    'time': 1524837600,
#    'uvIndex': 0,
#    'visibility': 9.45,
#    'windBearing': 178,
#    'windGust': 8.85,
#    'windSpeed': 4.82},
#   {'apparentTemperature': 53.99,
#    'cloudCover': 0.08,
#    'dewPoint': 47.28,
#    'humidity': 0.78,
#    'icon': 'clear-day',
#    'ozone': 369.1,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1018.7,
#    'summary': 'Clear',
#    'temperature': 53.99,
#    'time': 1524841200,
#    'uvIndex': 1,
#    'visibility': 9.49,
#    'windBearing': 192,
#    'windGust': 7.77,
#    'windSpeed': 5.99},
#   {'apparentTemperature': 56.46,
#    'cloudCover': 0.1,
#    'dewPoint': 47.32,
#    'humidity': 0.71,
#    'icon': 'clear-day',
#    'ozone': 365.45,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1019.01,
#    'summary': 'Clear',
#    'temperature': 56.46,
#    'time': 1524844800,
#    'uvIndex': 2,
#    'visibility': 10,
#    'windBearing': 200,
#    'windGust': 14.29,
#    'windSpeed': 9.09},
#   {'apparentTemperature': 59.46,
#    'cloudCover': 0.3,
#    'dewPoint': 46.51,
#    'humidity': 0.62,
#    'icon': 'partly-cloudy-day',
#    'ozone': 359.04,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1019.23,
#    'summary': 'Partly Cloudy',
#    'temperature': 59.46,
#    'time': 1524848400,
#    'uvIndex': 3,
#    'visibility': 9.44,
#    'windBearing': 217,
#    'windGust': 11.77,
#    'windSpeed': 8.42},
#   {'apparentTemperature': 61.22,
#    'cloudCover': 0.29,
#    'dewPoint': 46.42,
#    'humidity': 0.58,
#    'icon': 'partly-cloudy-day',
#    'ozone': 354.98,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1019.44,
#    'summary': 'Partly Cloudy',
#    'temperature': 61.22,
#    'time': 1524852000,
#    'uvIndex': 5,
#    'visibility': 9.49,
#    'windBearing': 213,
#    'windGust': 12.21,
#    'windSpeed': 8.32},
#   {'apparentTemperature': 63.02,
#    'cloudCover': 0.37,
#    'dewPoint': 46.02,
#    'humidity': 0.54,
#    'icon': 'partly-cloudy-day',
#    'ozone': 355.53,
#    'precipIntensity': 0.0004,
#    'precipProbability': 0.1,
#    'precipType': 'rain',
#    'pressure': 1019.37,
#    'summary': 'Partly Cloudy',
#    'temperature': 63.02,
#    'time': 1524855600,
#    'uvIndex': 6,
#    'visibility': 9.49,
#    'windBearing': 217,
#    'windGust': 13.6,
#    'windSpeed': 8.42},
#   {'apparentTemperature': 65.35,
#    'cloudCover': 0.33,
#    'dewPoint': 46.44,
#    'humidity': 0.5,
#    'icon': 'partly-cloudy-day',
#    'ozone': 358.32,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1018.93,
#    'summary': 'Partly Cloudy',
#    'temperature': 65.35,
#    'time': 1524859200,
#    'uvIndex': 7,
#    'visibility': 9.65,
#    'windBearing': 222,
#    'windGust': 13.77,
#    'windSpeed': 9.68},
#   {'apparentTemperature': 66.33,
#    'cloudCover': 0.23,
#    'dewPoint': 45.84,
#    'humidity': 0.48,
#    'icon': 'clear-day',
#    'ozone': 360.83,
#    'precipIntensity': 0.0001,
#    'precipProbability': 0.05,
#    'precipType': 'rain',
#    'pressure': 1018.54,
#    'summary': 'Clear',
#    'temperature': 66.33,
#    'time': 1524862800,
#    'uvIndex': 7,
#    'visibility': 9.72,
#    'windBearing': 232,
#    'windGust': 14.75,
#    'windSpeed': 9.91},
#   {'apparentTemperature': 67.4,
#    'cloudCover': 0.31,
#    'dewPoint': 45.97,
#    'humidity': 0.46,
#    'icon': 'partly-cloudy-day',
#    'ozone': 362.34,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1018.09,
#    'summary': 'Partly Cloudy',
#    'temperature': 67.4,
#    'time': 1524866400,
#    'uvIndex': 5,
#    'visibility': 10,
#    'windBearing': 228,
#    'windGust': 13.3,
#    'windSpeed': 9.98},
#   {'apparentTemperature': 67.86,
#    'cloudCover': 0.2,
#    'dewPoint': 45.78,
#    'humidity': 0.45,
#    'icon': 'clear-day',
#    'ozone': 363.53,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1017.68,
#    'summary': 'Clear',
#    'temperature': 67.86,
#    'time': 1524870000,
#    'uvIndex': 3,
#    'visibility': 9.83,
#    'windBearing': 235,
#    'windGust': 15.51,
#    'windSpeed': 9.36},
#   {'apparentTemperature': 67.58,
#    'cloudCover': 0.16,
#    'dewPoint': 45.19,
#    'humidity': 0.45,
#    'icon': 'clear-day',
#    'ozone': 360.66,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1017.42,
#    'summary': 'Clear',
#    'temperature': 67.58,
#    'time': 1524873600,
#    'uvIndex': 2,
#    'visibility': 9.85,
#    'windBearing': 228,
#    'windGust': 16.05,
#    'windSpeed': 12.41},
#   {'apparentTemperature': 66.27,
#    'cloudCover': 0.1,
#    'dewPoint': 45.86,
#    'humidity': 0.48,
#    'icon': 'clear-day',
#    'ozone': 361.28,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1017.31,
#    'summary': 'Clear',
#    'temperature': 66.27,
#    'time': 1524877200,
#    'uvIndex': 1,
#    'visibility': 9.87,
#    'windBearing': 226,
#    'windGust': 15.99,
#    'windSpeed': 13.25},
#   {'apparentTemperature': 63.78,
#    'cloudCover': 0.07,
#    'dewPoint': 45.56,
#    'humidity': 0.51,
#    'icon': 'clear-day',
#    'ozone': 362.02,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1017.23,
#    'summary': 'Clear',
#    'temperature': 63.78,
#    'time': 1524880800,
#    'uvIndex': 0,
#    'visibility': 9.89,
#    'windBearing': 231,
#    'windGust': 15.64,
#    'windSpeed': 12.66},
#   {'apparentTemperature': 60.18,
#    'cloudCover': 0,
#    'dewPoint': 45.89,
#    'humidity': 0.59,
#    'icon': 'clear-night',
#    'ozone': 362.32,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1017.52,
#    'summary': 'Clear',
#    'temperature': 60.18,
#    'time': 1524884400,
#    'uvIndex': 0,
#    'visibility': 9.8,
#    'windBearing': 229,
#    'windGust': 15.68,
#    'windSpeed': 11.48},
#   {'apparentTemperature': 56.82,
#    'cloudCover': 0,
#    'dewPoint': 46.15,
#    'humidity': 0.67,
#    'icon': 'clear-night',
#    'ozone': 361.35,
#    'precipIntensity': 0.0001,
#    'precipProbability': 0.03,
#    'precipType': 'rain',
#    'pressure': 1017.88,
#    'summary': 'Clear',
#    'temperature': 56.82,
#    'time': 1524888000,
#    'uvIndex': 0,
#    'visibility': 9.79,
#    'windBearing': 228,
#    'windGust': 12.77,
#    'windSpeed': 7.68},
#   {'apparentTemperature': 55.17,
#    'cloudCover': 0,
#    'dewPoint': 46.06,
#    'humidity': 0.71,
#    'icon': 'clear-night',
#    'ozone': 359.87,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1018.24,
#    'summary': 'Clear',
#    'temperature': 55.17,
#    'time': 1524891600,
#    'uvIndex': 0,
#    'visibility': 9.95,
#    'windBearing': 224,
#    'windGust': 10.52,
#    'windSpeed': 8.19},
#   {'apparentTemperature': 53.57,
#    'cloudCover': 0,
#    'dewPoint': 46.16,
#    'humidity': 0.76,
#    'icon': 'clear-night',
#    'ozone': 359.41,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1018.24,
#    'summary': 'Clear',
#    'temperature': 53.57,
#    'time': 1524895200,
#    'uvIndex': 0,
#    'visibility': 9.96,
#    'windBearing': 213,
#    'windGust': 9.05,
#    'windSpeed': 5.93}],
#  'icon': 'partly-cloudy-day',
#  'summary': 'Partly cloudy starting in the morning, continuing until afternoon.'}

# %%
davis['daily']
# Out:
# {'data': [{'apparentTemperatureHigh': 67.86,
#    'apparentTemperatureHighTime': 1524870000,
#    'apparentTemperatureLow': 47.01,
#    'apparentTemperatureLowTime': 1524913200,
#    'apparentTemperatureMax': 67.86,
#    'apparentTemperatureMaxTime': 1524870000,
#    'apparentTemperatureMin': 50.17,
#    'apparentTemperatureMinTime': 1524834000,
#    'cloudCover': 0.13,
#    'dewPoint': 45.85,
#    'humidity': 0.66,
#    'icon': 'partly-cloudy-day',
#    'moonPhase': 0.43,
#    'ozone': 358.71,
#    'precipIntensity': 0,
#    'precipIntensityMax': 0.0004,
#    'precipIntensityMaxTime': 1524855600,
#    'precipProbability': 0,
#    'pressure': 1017.35,
#    'summary': 'Partly cloudy until afternoon.',
#    'sunriseTime': 1524834923,
#    'sunsetTime': 1524884162,
#    'temperatureHigh': 67.86,
#    'temperatureHighTime': 1524870000,
#    'temperatureLow': 48.72,
#    'temperatureLowTime': 1524920400,
#    'temperatureMax': 67.86,
#    'temperatureMaxTime': 1524870000,
#    'temperatureMin': 50.17,
#    'temperatureMinTime': 1524834000,
#    'time': 1524812400,
#    'uvIndex': 7,
#    'uvIndexTime': 1524859200,
#    'visibility': 9.75,
#    'windBearing': 216,
#    'windGust': 20.15,
#    'windGustTime': 1524823200,
#    'windSpeed': 8.7}]}
